# %%
#Import packages
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

#Open image file
image = Image.open('C:/Users/Computer Science Lap/Downloads/MICC-F8multi/1 (1).jpg')
ik = cv2.imread('C:/Users/Computer Science Lap/Downloads/MICC-F8multi/1 (1).jpg',0)

plt.imshow(image)

#Image Array
ia = np.array(image)

i_red = ia.copy()
i_red[:,:,1]=0
i_red[:,:,2]=0
plt.title("Red Channel")
plt.imshow(i_red)
plt.show()

i_green = ia.copy()
i_green[:,:,0]=0
i_green[:,:,2]=0
plt.title("Green Channel")
plt.imshow(i_green)
plt.show()

i_blue = ia.copy()
i_blue[:,:,0]=0
i_blue[:,:,1]=0
plt.title("Blue channel")
plt.imshow(i_blue)
plt.show()

i_rgb = ((i_red[:,:,0])//3 + (i_blue[:,:,2])//3 + (i_green[:,:,1])//3)
plt.title("Conerted grey level Imgae channel")
plt.imshow(i_rgb)
plt.show()

import cv2
cv2.imshow('converted grey level image',i_rgb)
cv2.waitKey(0)
cv2.destroyAllWindows()
